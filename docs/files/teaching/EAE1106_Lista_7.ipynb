# %% [markdown]
# # EAE1106 - Métodos Computacionais para Economia
# **Faculdade de Economia, Administração, Contabilidade e Atuária (FEA-USP)**
#
# ---
#
# **Professor:** Arthur Augusto Viaro
# **Monitora:** Cinthya Beneducci Afonso ([cinthyabeneducci@usp.br](mailto:cinthyabeneducci@usp.br))
#
# ---
#
#
# ## Lista de Exercícios: Visualização de Dados
# **Referência:** Aulas 22 e 23 (Matplotlib, Seaborn e Plotly)
#
# *Instruções:* Leia atentamente cada enunciado e utilize os blocos de código abaixo de cada questão para construir e testar as suas respostas. Lembre-se de rodar as células para verificar se o resultado é o esperado!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 5
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 5 import plotly as px
#
# ModuleNotFoundError: No module named 'plotly'

# %% [markdown]
# ### Exercício 1: Gráfico de Linha Básico
# A taxa básica de juros (Selic) de uma economia hipotética foi registrada ao longo de um ano conforme o vetor abaixo.
#
# Utilizando exclusivamente a biblioteca Matplotlib:
# 1. Plote um gráfico de linha mostrando a evolução da Selic ao longo dos meses.
# 2. Altere a cor da linha para vermelho, adicione um marcador circular em cada ponto e configure a linha para ser tracejada.
# 3. Adicione títulos informativos nos eixos X e Y, além de um título principal para o gráfico.

# %%
### SUA RESPOSTA AQUI ###
meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
selic = [13.75, 13.75, 13.75, 13.50, 13.25, 12.75, 12.75, 12.50, 12.25, 11.75, 11.50, 11.25]

# %% [markdown]
# ### Exercício 2: Gráfico de Barras com Seaborn
# Utilizando o conjunto de dados embutido "`tips`" da biblioteca Seaborn, realize uma análise visual sobre as gorjetas recebidas.
#
# 1. Carregue o dataset utilizando a função apropriada do Seaborn.
# 2. Crie um gráfico de barras vertical apresentando a média do valor da conta total (coluna "total_bill") para cada dia da semana (coluna "day").
# 3. Remova as barras de erro padrão do gráfico para manter o visual mais limpo.

# %%
### SUA RESPOSTA AQUI ###

# %% [markdown]
# ### Exercício 3: Múltiplos Subplots com Matplotlib
# Uma consultoria econômica coletou dados sobre o crescimento do PIB e a taxa de desemprego de um país ao longo de cinco anos.
#
# Utilizando o método orientado a objetos do Matplotlib (plt.subplots):
# 1. Crie uma única figura contendo uma linha e duas colunas de gráficos (1x2).
# 2. No primeiro gráfico (à esquerda), plote o crescimento do PIB em barras da cor azul.
# 3. No segundo gráfico (à direita), plote a taxa de desemprego em uma linha contínua da cor preta.
# 4. Garanta que cada subplot tenha seu próprio título e eixos rotulados adequadamente.

# %%
### SUA RESPOSTA AQUI ###
anos = [2019, 2020, 2021, 2022, 2023]
pib = [2.2, -4.1, 4.8, 2.9, 3.1]
desemprego = [11.9, 13.5, 11.1, 9.3, 7.8]

# %% [markdown]
# ### Exercício 4: Gráfico de Dispersão Agrupado com Seaborn
# Retorne ao conjunto de dados "`tips`" do Seaborn para investigar o comportamento dos clientes.
#
# 1. Construa um gráfico de dispersão relacionando o valor total da conta ("total_bill") no eixo X e o valor da gorjeta ("tip") no eixo Y.
# 2. Utilize o parâmetro de agrupamento por cor para diferenciar os clientes entre fumantes e não fumantes ("smoker").
# 3. Utilize o parâmetro de estilo de marcador para diferenciar o período do dia ("time").
# 4. Posicione a legenda em um local que não sobreponha os pontos do gráfico.

# %%
### SUA RESPOSTA AQUI ###

# %% [markdown]
# ### Exercício 5: Visualização Interativa com Plotly Express
# O Plotly Express permite criar gráficos dinâmicos altamente informativos para apresentações executivas.
#
# 1. Carregue os dados históricos mundiais do Gapminder que já vêm embutidos no Plotly Express ("`px.data.gapminder()`").
# 2. Filtre o DataFrame para conter apenas as observações referentes ao ano de 2007.
# 3. Crie um gráfico de dispersão interativo relacionando o PIB per capita ("gdpPercap") no eixo X e a expectativa de vida ("lifeExp") no eixo Y.
# 4. Defina o tamanho dos pontos proporcionalmente à população do país ("pop") e a cor dos pontos mapeada de acordo com o continente ("continent").

# %%
### SUA RESPOSTA AQUI ###

# %% [markdown]
# ### Exercício 6: Mapa de Calor de Correlação
# Em modelos econométricos, avaliar a colinearidade entre as variáveis é um passo fundamental antes da estimação.
#
# 1. Utilizando o dataset "`tips`", isole apenas as colunas numéricas existentes no DataFrame.
# 2. Calcule a matriz de correlação linear de Pearson para estas variáveis.
# 3. Plote um mapa de calor (heatmap) utilizando o Seaborn para representar visualmente as correlações.
# 4. Configure o gráfico para exibir os valores numéricos dentro de cada quadrado, utilize uma paleta de cores divergente apropriada e ajuste o limite de intensidade da cor para variar estritamente entre -1 e 1.

# %%
### SUA RESPOSTA AQUI ###

# %% [markdown]
# ### Exercício 7: Redução de Sujeira Gráfica e Princípios de Schwabish
# Jonathan Schwabish defende que um bom gráfico deve focar nos dados e remover decorações desnecessárias (sujeira gráfica). Considere a série temporal de inflação abaixo.
#
# Utilizando o Matplotlib de forma avançada, crie um gráfico que siga estritamente estas regras de design:
# 1. Plote a linha de inflação com uma espessura destacada e cor cinza escura ou azul marinho.
# 2. Remova completamente as bordas (spines) superior e direita do gráfico.
# 3. Adicione linhas de grade apenas horizontais, configuradas com uma cor cinza muito clara e estilo tracejado, evitando poluir o plano de fundo.
# 4. Em vez de uma legenda padrão, adicione um texto direto no final da linha (utilizando plt.text) identificando a série.

# %%
### SUA RESPOSTA AQUI ###
anos = list(range(2014, 2024))
inflacao = [6.41, 10.67, 6.29, 2.95, 3.75, 4.31, 4.52, 10.06, 5.79, 4.62]

# %% [markdown]
# ### Exercício 8: Distribuições Facetadas com Seaborn
# Análise de dados demográficos complexos exige ferramentas que separem as informações de forma sistemática por categorias.
#
# Utilizando o dataset "`titanic`" embutido no Seaborn e as funções de nível de figura (figure-level):
# 1. Carregue o conjunto de dados do Titanic.
# 2. Utilize a função "displot" para gerar curvas de estimativa de densidade de kernel (KDE) para a idade ("age") dos passageiros.
# 3. Separe as curvas por cor de acordo com a classe em que o passageiro viajava ("pclass").
# 4. Facete o gráfico em colunas separadas de acordo com o sexo do passageiro ("sex"), gerando dois subplots paralelos automaticamente gerenciados pela função do Seaborn.
# 5. Ajuste os rótulos dos eixos e adicione um título global acima da figura.

# %%
### SUA RESPOSTA AQUI ###
