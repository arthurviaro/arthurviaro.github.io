# %% [markdown]
# # EAE1106 - Métodos Computacionais para Economia
# **Faculdade de Economia, Administração, Contabilidade e Atuária (FEA-USP)**
#
# ---
#
# **Professor:** Arthur Augusto Viaro
# **Monitora:** Cinthya Beneducci Afonso ([cinthyabeneducci@usp.br](mailto:cinthyabeneducci@usp.br))
#
# ---
#
# ## Lista de Exercícios 6
# **Temática:** Pandas
#
# *Instruções:* Leia atentamente cada enunciado e utilize os blocos de código abaixo de cada questão para construir e testar as suas respostas. Lembre-se de rodar as células para verificar se o resultado é o esperado!

# %%
import pandas as pd
import seaborn as sns
import statsmodels.api as sm

# obs.: instale com "!pip" se necessário

# %% [markdown]
# ### Exercício 1: Transformação e Agrupamento
# O dataset `tips` contém dados sobre gorjetas dadas num restaurante.
# Carregue os dados usando: `df_tips = sns.load_dataset("tips")`
#
# 1. Crie uma nova coluna chamada `tip_pct` que represente a gorjeta (`tip`) como uma percentagem da conta total (`total_bill`).
# 2. Utilizando o `groupby`, descubra qual dia da semana (`day`) tem a **maior média** de percentagem de gorjeta.
# 3. No mesmo `groupby`, descubra também a média da conta total por dia.

# %%
### SUA RESPOSTA AQUI ###
df_tips = sns.load_dataset("tips")
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Exercício 2: Tabelas Dinâmicas e input inteligente
# O dataset `titanic` contém dados dos passageiros do famoso navio.
# Carregue os dados usando: `df_titanic = sns.load_dataset("titanic")`
#
# A coluna `age` (idade) possui vários valores faltantes (`NaN`). Se preenchermos tudo com a média geral, vamos distorcer os dados.
# 1. Preencha os valores faltantes da coluna `age` com a **mediana da idade da respectiva classe do passageiro** (`pclass`). *(Dica: Use `groupby` combinado com `transform` e `fillna`).*
# 2. Após preencher os dados, crie uma tabela dinâmica (`pivot_table`) que mostre a **taxa de sobrevivência média** (`survived`) com o sexo (`sex`) nas linhas e a classe (`pclass`) nas colunas.

# %%
### SUA RESPOSTA AQUI ###
df_titanic = sns.load_dataset("titanic")
df_titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ### Exercício 3: Séries Temporais e Variação Percentual
# O pacote `statsmodels` possui um dataset macroeconómico clássico dos EUA.
# Carregue os dados usando: `df_macro = sm.datasets.macrodata.load_pandas().data`
#
# 1. A coluna `realgdp` contém o PIB real trimestral. Crie uma nova coluna chamada `crescimento_pib` que calcule a variação percentual do PIB em relação ao trimestre imediatamente anterior. *(Dica: explore o método `.pct_change()` do Pandas).*
# 2. Multiplique essa nova coluna por 100 para ficar em formato de percentagem (ex: 1.5 em vez de 0.015).
# 3. Isole e imprima os **5 trimestres** (linhas) que tiveram o maior crescimento percentual na história do dataset. Use o método `.nlargest()`.

# %%
### SUA RESPOSTA AQUI ###
df_macro = sm.datasets.macrodata.load_pandas().data
df_macro
# Out:
#        year  quarter    realgdp  realcons   realinv  realgovt  realdpi  \
# 0    1959.0      1.0   2710.349    1707.4   286.898   470.045   1886.9
# 1    1959.0      2.0   2778.801    1733.7   310.859   481.301   1919.7
# 2    1959.0      3.0   2775.488    1751.8   289.226   491.260   1916.4
# 3    1959.0      4.0   2785.204    1753.7   299.356   484.052   1931.3
# 4    1960.0      1.0   2847.699    1770.5   331.722   462.199   1955.5
# ..      ...      ...        ...       ...       ...       ...      ...
# 198  2008.0      3.0  13324.600    9267.7  1990.693   991.551   9838.3
# 199  2008.0      4.0  13141.920    9195.3  1857.661  1007.273   9920.4
# 200  2009.0      1.0  12925.410    9209.2  1558.494   996.287   9926.4
# 201  2009.0      2.0  12901.504    9189.0  1456.678  1023.528  10077.5
# 202  2009.0      3.0  12990.341    9256.0  1486.398  1044.088  10040.6
#
#          cpi      m1  tbilrate  unemp      pop  infl  realint
# ...

# %% [markdown]
# ### Exercício 4: Aplicando Funções Customizadas
# O dataset `flights` mostra o número de passageiros por mês ao longo dos anos.
# Carregue os dados usando: `df_voos = sns.load_dataset("flights")`
#
# 1. Crie uma função Python normal (usando `def`) chamada `classifica_temporada(mes)` que receba o nome de um mês (em inglês) e retorne `"Alta"` se o mês for 'Jul' ou 'Aug', e `"Baixa"` para os demais.
# 2. Utilize o método `.apply()` para aplicar esta função à coluna `month` e crie uma nova coluna chamada `temporada`.
# 3. Calcule o total de passageiros (`passengers`) que viajaram na Alta e na Baixa temporada em todo o período do dataset.

# %%
### SUA RESPOSTA AQUI ###
df_voos = sns.load_dataset("flights")
df_voos
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %% [markdown]
# ### Exercício: Rolling Windows
# Vamos voltar ao dataset macroeconómico:
# `df_macro = sm.datasets.macrodata.load_pandas().data`
#
# A coluna `infl` representa a inflação trimestral. Analisar a inflação trimestre a trimestre pode ser muito volátil.
# 1. Crie uma nova coluna chamada `inflacao_anualizada_media` que calcule a **média móvel dos últimos 4 trimestres** da coluna `infl`. *(Dica: explore o método `.rolling(window=...)` encadeado com `.mean()`).*
# 2. Repare que as primeiras 3 linhas ficarão com valores `NaN` (pois não há 4 trimestres para trás para calcular a média). Remova essas linhas do DataFrame utilizando `.dropna()`.
# 3. Descubra a proporção (em percentagem) de trimestres em que essa média móvel de inflação superou os 5%.

# %%
### SUA RESPOSTA AQUI ###

# %% [markdown]
# ### Exercício 6: Mesclagem de DataFrames (Left Join)
# Em finanças, os dados quase nunca estão numa única tabela. Considere os dois DataFrames simulados abaixo:
#
# `df_empresas` contém o Setor de cada Ticker de ações.
# `df_cotacoes` contém as variações de preço num determinado dia.
#
# 1. Faça a mesclagem (`merge`) dos dois DataFrames para trazer a informação do `Setor` para dentro da tabela de `Cotações`. Mantenha todas as cotações, mesmo que a empresa não esteja cadastrada na tabela de empresas (Left Join).
# 2. Repare que a "WEGE3" ficará com o setor nulo (`NaN`). Preencha este buraco com a string `"Indústria"`.
# 3. Calcule a variação média por Setor.

# %%
### SUA RESPOSTA AQUI ###

df_empresas = pd.DataFrame({
    'Ticker': ['PETR4', 'VALE3', 'ITUB4', 'BBAS3'],
    'Setor': ['Energia', 'Materiais', 'Financeiro', 'Financeiro']
})

df_cotacoes = pd.DataFrame({
    'Ticker': ['PETR4', 'VALE3', 'ITUB4', 'WEGE3', 'BBAS3'],
    'Variacao_Pct': [2.5, -1.0, 0.5, 1.2, 0.8]
})

# %% [markdown]
# ### Exercício 7: Remodelagem de Dados com `melt`
# Você baixou uma planilha do Banco Mundial com o PIB (em trilhões de US$) de três países. Como é comum nessas bases, os anos vieram como colunas separadas (formato *Wide*).
#
# 1. Utilize a função `pd.melt()` para transformar este DataFrame para o formato *Long*. O novo DataFrame deve ter apenas 3 colunas: `País`, `Ano` e `PIB`.
# 2. O tipo de dado da coluna `Ano` provavelmente ficará como texto (string). Converta a coluna `Ano` para o tipo numérico inteiro (`int`).
# 3. Descubra qual país teve o **maior PIB médio** no período.

# %%
### SUA RESPOSTA AQUI ###

df_pib_amplo = pd.DataFrame({
    'País': ['Brasil', 'México', 'Argentina'],
    '2020': [1.44, 1.09, 0.38],
    '2021': [1.60, 1.27, 0.48],
    '2022': [1.92, 1.41, 0.63]
})

# %% [markdown]
# ### Exercício 8: Empilhamento de Dados
# Você recebeu os dados de exportações brasileiras (em bilhões de US$) divididos em dois ficheiros diferentes: um para o 1º Semestre e outro para o 2º Semestre.
#
# 1. Antes de juntar, crie uma coluna chamada `Semestre` no `df_sem1` preenchida com o valor `1`, e no `df_sem2` preenchida com o valor `2`.
# 2. Utilize a função `pd.concat()` para empilhar os dois DataFrames verticalmente, criando o `df_ano_todo`. *(Dica: lembre-se do argumento `ignore_index=True` para resetar os índices).*
# 3. Agrupe os dados empilhados para descobrir o total exportado de cada `Produto` no ano inteiro.

# %%
### SUA RESPOSTA AQUI ###

df_sem1 = pd.DataFrame({
    'Produto': ['Soja', 'Minério de Ferro', 'Petróleo'],
    'Exportacao_Bi': [35.2, 22.1, 18.5]
})

df_sem2 = pd.DataFrame({
    'Produto': ['Soja', 'Minério de Ferro', 'Petróleo'],
    'Exportacao_Bi': [28.4, 25.3, 21.0]
})

# %% [markdown]
# ### Exercício 9: `.str`
# Uma corretora enviou o valor de mercado de quatro ativos financeiros, mas a coluna veio completamente "suja" com formatação de texto contendo a moeda, espaços em branco e pontuação brasileira.
#
# `df_ativos` contém a coluna `Valor_Mercado` com strings como `"R$ 1.500,50"`.
#
# Sua missão é transformar essa coluna em números decimais (`float`) para podermos fazer contas:
# 1. Use `.str.replace()` para remover a string `"R$ "`.
# 2. Use `.str.replace()` para remover o ponto de milhar `"."`.
# 3. Use `.str.replace()` para trocar a vírgula `","` por um ponto decimal `"."`.
# 4. Converta a coluna limpa para `float` utilizando o método `.astype(float)`.
# 5. Calcule a soma total do valor de mercado dos 4 ativos.

# %%
### SUA RESPOSTA AQUI ###

df_ativos = pd.DataFrame({
    'Ticker': ['PETR4', 'VALE3', 'ITUB4', 'WEGE3'],
    'Valor_Mercado': ['R$ 3.500,50', 'R$ 6.820,00', 'R$ 2.940,75', 'R$ 1.450,20']
})

# %% [markdown]
# ### Exercício 10: `datetime`
# Você recebeu a carteira de empréstimos de um banco. As datas de assinatura e vencimento dos contratos vieram como texto (strings) e o banco precisa de algumas métricas de prazo.
#
# 1. Converta as colunas `Data_Assinatura` e `Data_Vencimento` de texto (string) para o formato de data do Pandas utilizando a função `pd.to_datetime()`.
# 2. Crie uma nova coluna chamada `Prazo_Dias` que seja a diferença matemática entre a `Data_Vencimento` e a `Data_Assinatura`. *(Nota: O resultado será um tipo especial chamado `timedelta`. Para extrair apenas o número inteiro de dias, use `.dt.days`).*
# 3. Crie uma coluna chamada `Mes_Assinatura` extraindo apenas o mês da data de assinatura utilizando o acessor `.dt.month`.
# 4. **O Filtro Final:** Encontre todos os contratos que foram assinados no **segundo semestre** (mês >= 7) e que possuem um prazo **maior que 300 dias**.

# %%
### SUA RESPOSTA AQUI ###

df_contratos = pd.DataFrame({
    'ID_Contrato': ['C001', 'C002', 'C003', 'C004', 'C005'],
    'Data_Assinatura': ['2023-01-15', '2023-08-20', '2023-11-05', '2023-02-28', '2023-09-10'],
    'Data_Vencimento': ['2023-10-15', '2024-08-20', '2024-05-05', '2023-08-28', '2024-10-10'],
    'Valor_Emprestimo': [50000, 120000, 85000, 30000, 250000]
})

# Verifique o tipo atual das colunas (são 'object', ou seja, texto)
print("Tipos antes da conversão:")
print(df_contratos.dtypes)
print("-" * 30)
# Out:
# Tipos antes da conversão:
# ID_Contrato         object
# Data_Assinatura     object
# Data_Vencimento     object
# Valor_Emprestimo     int64
# dtype: object
# ------------------------------
