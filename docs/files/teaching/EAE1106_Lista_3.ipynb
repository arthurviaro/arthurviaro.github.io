# %% [markdown]
# # EAE1106 - Métodos Computacionais para Economia
# **Faculdade de Economia, Administração, Contabilidade e Atuária (FEA-USP)**
#
# ---
#
# **Professor:** Arthur Augusto Viaro  ([site](https://arthurviaro.github.io))
#
# **Monitora:** Cinthya Beneducci Afonso ([cinthyabeneducci@usp.br](mailto:cinthyabeneducci@usp.br)). Monitorias às quintas-feiras de 18h-19h, a cada duas semanas.
#
# ---
#
# ## Lista de Exercícios 3
# **Referência:** Aula 09 - Introdução às Funções
#
# *Instruções:* Leia atentamente cada enunciado e utilize os blocos de código abaixo de cada questão para construir e testar as suas respostas. Lembre-se de correr (executar) as células para verificar se o resultado é o esperado!

# %% [markdown]
# ### Exercício 1: Equação de Fisher
# **Referência: Aula 09**
#
# Na macroeconomia, a Equação de Fisher é utilizada para converter uma taxa de juros nominal em uma taxa de juros real, descontando a inflação. A fórmula exata é:
# $(1 + r) = \frac{1 + i}{1 + \pi}$
# Sendo $r$ a taxa real, $i$ a taxa nominal e $\pi$ a inflação.
#
# 1. Crie uma função chamada `calcular_taxa_real` que receba dois parâmetros: `taxa_nominal` e `inflacao` (ambos em formato decimal, por exemplo, 0.10 para 10%).
# 2. Dentro da função, calcule a taxa de juros real ($r$) isolando-a na fórmula acima.
# 3. Utilize a palavra-chave `return` para que a função devolva o valor da taxa real.
# 4. Teste a sua função passando uma taxa nominal de `0.12` (12%) e uma inflação de `0.05` (5%). Imprima o resultado na tela formatado como percentagem (ex: `:.2%`).

# %%
### SUA RESPOSTA AQUI ###

# %% [markdown]
# ### Exercício 2: Simulador de Financiamento
# **Referência: Aula 09**
#
# No mercado de crédito, muitas vezes as taxas base são padronizadas, a menos que o cliente tenha condições especiais.
#
# 1. Crie uma função chamada `simular_emprestimo` que receba três parâmetros: `principal` (o valor do empréstimo), `prazo_anos` e `taxa_anual`.
# 2. Defina um **valor padrão (default)** de `0.08` (8%) para o parâmetro `taxa_anual`.
# 3. Adicione uma **Docstring** (usando aspas triplas `"""`) logo abaixo da definição da função, explicando brevemente o que a função faz, quais são os parâmetros e o que ela retorna.
# 4. A função deve calcular e retornar o montante final usando juros simples: $M = P \times (1 + (t \times n))$, onde $t$ é a taxa e $n$ é o prazo.
# 5. Chame a função duas vezes e imprima os resultados: uma vez passando apenas o principal (`10000`) e o prazo (`5`), e outra vez passando também uma taxa personalizada de `0.05`.

# %%
### SUA RESPOSTA AQUI ###

# %% [markdown]
# ### Exercício 3: *Throubleshooting*
# **Referência: Aula 09**
#
# O código abaixo tenta atualizar o saldo da balança comercial de um país após uma nova exportação, mas algo está errado devido ao **escopo das variáveis** (Local vs. Global).
#
# ```python
# saldo_comercial = 500.0  # (em milhões)
#
# def registar_exportacao(valor_exportado):
#     saldo_comercial = saldo_comercial + valor_exportado
#     print(f"Novo saldo interno: {saldo_comercial}")
#
# registar_exportacao(150.0)
# print(f"Saldo final global: {saldo_comercial}")
# ```
#
# Copie o código acima para a sua célula de resposta e tente corrê-lo. Vai reparar que o Python devolve um erro ```(UnboundLocalError)```.
#
# Conserte a função utilizando a palavra-chave que avisa o Python que quer modificar a variável que está de fora da função, e não criar uma nova variável local.
#
# Corra o código novamente e garanta que o saldo final impresso seja 650.0.

# %%
### SUA RESPOSTA AQUI ###

# %% [markdown]
# ### Exercício 4: Agregador de Receitas Públicas
# **Referência: Aula 09**
#
# O Ministério das Finanças precisa de consolidar várias fontes de receita. Como o número de impostos pode variar a cada mês, as funções precisam de ser flexíveis.
#
# 1. Crie uma função chamada `consolidar_receitas` que aceite um número variável de receitas correntes não nomeadas usando `*args`, e um número variável de receitas extraordinárias nomeadas usando `**kwargs`.
# 2. Dentro da função, calcule a soma total de todas as receitas em `args`.
# 3. Em seguida, percorra os itens de `kwargs` (lembre-se do método `.items()` dos dicionários) e some os seus valores ao total.
# 4. A função deve imprimir um mini-relatório mostrando o total arrecadado e listando os nomes das receitas extraordinárias que foram passadas.
# 5. Teste a função chamando: `consolidar_receitas(100, 250, 50, privatizacao=500, concessoes=300)`.

# %%
### SUA RESPOSTA AQUI ###

# %% [markdown]
# ### Exercício 5: Ordenando fundos
# **Referência: Aula 09**
#
# A função `sorted()` é muito poderosa para ordenar dados, especialmente quando combinada com funções anónimas (`lambda`). Considere a seguinte lista de tuplas, onde cada tupla representa um Fundo de Investimento, contendo `(Nome, Retorno_%, Risco_%)`:
#
# `fundos = [("Fundo Alfa", 12.5, 8.2), ("Fundo Beta", 9.0, 4.1), ("Fundo Gama", 15.2, 11.5)]`
#
# 1. Utilize a função `sorted()` para criar uma nova lista chamada `ranking_retorno`, ordenando os fundos do **maior para o menor retorno** (ordem decrescente). Use uma função `lambda` no parâmetro `key` para indicar que a ordenação deve ser feita pelo segundo elemento da tupla (índice 1).
# 2. Utilize a função `sorted()` novamente para criar uma lista chamada `ranking_risco`, ordenando os fundos do **menor para o maior risco** (ordem crescente). Use uma função `lambda` no parâmetro `key` apontando para o terceiro elemento da tupla (índice 2).
# 3. Imprima ambas as listas resultantes.

# %%
### SUA RESPOSTA AQUI ###

# %% [markdown]
# ### Exercício 6: Divisão de trabalho
# **Referência: Aula 09**
#
# Na programação estruturada, é uma boa prática criar "funções auxiliares" que realizam tarefas pequenas e específicas, para então usá-las dentro de funções maiores. Vamos calcular o custo total de importar um equipamento, dividindo o problema em duas etapas.
#
# 1. **A Função Auxiliar:** Crie uma função chamada `converter_para_reais(valor_dolar, cotacao_dolar)`. Ela deve simplesmente multiplicar os dois parâmetros e retornar o valor em reais (BRL).
# 2. **A Função Principal:** Crie uma segunda função chamada `calcular_custo_importacao(valor_dolar, cotacao_dolar, aliquota_imposto)`.
# 3. **A Integração:** Dentro da função `calcular_custo_importacao`, chame a função `converter_para_reais()` para descobrir o valor base do equipamento em reais. Salve esse resultado em uma variável.
# 4. **O Cálculo Final:** Calcule o custo total multiplicando o valor base em reais por `(1 + aliquota_imposto)`. Faça a função principal **retornar** esse custo total.
# 5. **O Teste:** Chame a sua função principal simulando a compra de um maquinário de US$ 5.000, com o dólar a R$ 5,20 e um imposto de importação de 60% (0.60). Imprima o resultado final na tela.

# %%
### SUA RESPOSTA AQUI ###
