# %% [markdown]
# # EAE1106 - Métodos Computacionais para Economia
# **Faculdade de Economia, Administração, Contabilidade e Atuária (FEA-USP)**
#
# ---
#
# **Professor:** Arthur Augusto Viaro  ([site](https://arthurviaro.github.io))
#
# **Monitora:** Cinthya Beneducci Afonso ([cinthyabeneducci@usp.br](mailto:cinthyabeneducci@usp.br)). Monitorias às quintas-feiras de 18h-19h, a cada duas semanas.
#
# ---
#
# ## Lista de Exercícios 2
# **Referência:** Aulas 05 a 08 (Listas, Tuplas, Conjuntos, Dicionários, Condicionais e Repetições)
#
# *Instruções:* Leia atentamente cada enunciado e utilize os blocos de código abaixo de cada questão para construir e testar as suas respostas. Lembre-se de rodar as células para verificar se o resultado é o esperado!

# %% [markdown]
# ### Exercício 1: Revisão do IPCA
#
# Você recebeu uma lista com as taxas mensais de inflação (IPCA) do último semestre:
# `ipca_semestre = [0.53, 0.84, 0.71, 0.61, 0.23, 0.28]`
#
# O IBGE informou que houve um erro de cálculo no terceiro mês e a taxa correta foi de `0.65`.
# 1. Sabendo que listas são **mutáveis**, corrija o valor do terceiro mês diretamente na lista (lembre-se de como o Python conta os índices!).
# 2. Adicione a inflação do novo mês (o sétimo mês), que foi de `0.15`, ao final da lista utilizando o método apropriado.
# 3. Usando o **fatiamento (slicing)**, crie uma nova variável contendo apenas a inflação do último trimestre (os 3 últimos valores da lista atualizada) e imprima na tela.

# %%
### SUA RESPOSTA AQUI ###

# %% [markdown]
# ### Exercício 2: *Zip it!*
#
# Você extraiu dados de duas APIs diferentes. Uma te retornou uma tupla com os nomes dos países, e a outra te retornou uma tupla com a taxa básica de juros atual de cada um:
#
# `paises = ("Brasil", "EUA", "Zona do Euro", "Japão")`
# `taxas_juros = (10.50, 5.25, 4.00, 0.10)`
#
# 1. Utilize as funções `list()` e `zip()` juntas para combinar essas duas tuplas em uma lista de pares (tuplas). Salve o resultado em uma variável chamada `dados_globais` e imprima-a na tela.
# 2. No mercado financeiro, buscar a taxa de um país específico em uma lista de tuplas não é eficiente. Sabendo disso, utilize a função `dict(zip(...))` para combinar as duas tuplas originais diretamente em um **dicionário**. Em seguida, acesse e imprima apenas a taxa de juros do `"Japão"` usando a chave do dicionário.
# 3. Agora, imagine que você precisa reverter o processo feito no passo 1. Pegue a sua variável `dados_globais` (que é uma lista de tuplas) e utilize a função `zip()` combinada com o **operador de desempacotamento (`*`)** para separar os dados de volta em duas tuplas distintas: `paises_recuperados` e `taxas_recuperadas`. Imprima essas duas novas tuplas para provar que a separação funcionou.

# %%
### SUA RESPOSTA AQUI ###

# %% [markdown]
# ### Exercício 3: Interseção de Portfólios
#
# Você está analisando a carteira de ações de dois fundos de investimento diferentes. O Python permite usar **Conjuntos (Sets)** para realizar operações de teoria dos conjuntos de forma muito eficiente.
#
# `fundo_dinamico = {"PETR4", "VALE3", "ITUB4", "WEGE3", "SUZB3"}`
# `fundo_conservador = {"ITUB4", "BBAS3", "TAEE11", "VALE3", "EGIE3"}`
#
# Usando os métodos ou operadores de conjuntos adequados, calcule e imprima:
# 1. Os ativos que estão presentes **em ambos** os fundos (Interseção).
# 2. Todos os ativos únicos que compõem o mercado de análise (A união dos dois fundos).
# 3. Os ativos que o Fundo Dinâmico possui, mas que o Fundo Conservador **não** possui (Diferença).

# %%
### SUA RESPOSTA AQUI ###

# %% [markdown]
# ### Exercício 4: O Boletim Macro
#
# Os dicionários são a base para trabalhar com dados no formato JSON, muito comum na raspagem de dados web. Crie um dicionário vazio chamado `boletim_macro` e faça as seguintes operações:
#
# 1. Adicione a chave `"ano"` com o valor `2026`.
# 2. Adicione a chave `"pib_crescimento"` com o valor `2.5`.
# 3. Adicione a chave `"meta_selic"` com o valor `9.0`.
# 4. O Copom acabou de se reunir e decidiu baixar a taxa Selic em 0.5 ponto percentual. Atualize o valor da chave `"meta_selic"` no seu dicionário subtraindo 0.5 do valor atual.
# 5. Imprima o dicionário completo para conferência.
# 6. Usando um laço `for` combinado com o método `.items()`, percorra o seu dicionário e imprima cada item no seguinte formato usando f-string: `"A chave [nome_da_chave] armazena o valor [valor]"`.

# %%
### SUA RESPOSTA AQUI ###

# %% [markdown]
# ### Exercício 5: Regra de Taylor Simplificada
#
# O Banco Central toma decisões sobre a taxa de juros observando o desvio da inflação em relação à meta. Crie um programa que defina as seguintes variáveis:
# `inflacao_atual = 5.8`
# `meta_inflacao = 3.0`
# `banda_tolerancia = 1.5`
#
# Crie uma estrutura condicional (`if`, `elif`, `else`) que:
# 1. Se a inflação atual for **maior** que a meta somada à banda de tolerância, imprima: `"Aumentar taxa Selic drasticamente"`.
# 2. Se a inflação for **maior** que a meta, mas ainda estiver **dentro** da banda de tolerância (ou seja, menor ou igual à meta + banda), imprima: `"Aumentar taxa Selic moderadamente"`.
# 3. Caso contrário, imprima: `"Manter ou reduzir taxa Selic"`.

# %%
### SUA RESPOSTA AQUI ###

# %% [markdown]
# ### Exercício 6: Classificação de Risco
#
# As agências de classificação de risco (Rating) avaliam a capacidade de um país pagar suas dívidas.
#
# Crie uma variável `rating_pais = "BB"` e faça uma estrutura `match` que verifique essa variável e imprima:
# * Caso seja `"AAA"`, `"AA"` ou `"A"` (use a barra vertical `|` para agrupar as três opções): imprima `"Grau de Investimento Alto"`.
# * Caso seja `"BBB"`: imprima `"Grau de Investimento Médio"`.
# * Caso seja `"BB"`, `"B"` ou `"CCC"`: imprima `"Grau Especulativo"`.
# * Caso seja qualquer outra coisa (`_`): imprima `"Rating em default ou não reconhecido"`.

# %%
### SUA RESPOSTA AQUI ###

# %% [markdown]
# ### Exercício 7: Corrigindo Valores Históricos
#
# Você recebeu uma lista com a cotação histórica do dólar em diferentes anos, mas percebeu que a base de dados enviou os valores multiplicados por 100 (ex: 520 em vez de 5.20).
#
# `dolar_historico = [415, 520, 545, 490, 510]`
#
# 1. Crie uma nova lista vazia chamada `dolar_corrigido`.
# 2. Usando um laço `for`, percorra cada valor na lista `dolar_historico`.
# 3. Dentro do laço, divida o valor por 100 e adicione (usando o método `.append()`) esse novo valor à lista `dolar_corrigido`.
# 4. Imprima a lista `dolar_corrigido` no final.

# %%
### SUA RESPOSTA AQUI ###

# %% [markdown]
# ### Exercício 8: A Magia dos Juros Compostos
# **Referência: Aula 08**
#
# Você tem um cliente que deseja se aposentar com um patrimônio de R$ 1.000.000,00 (1 milhão). Atualmente, ele possui um patrimônio inicial de R$ 200.000,00 aplicado em um título público que rende 8% ao ano (0.08).
#
# Crie um programa que utilize um laço `while()` para descobrir **quantos anos** levará para ele atingir a marca de 1 milhão.
#
# Imprima na tela a frase: `"Levará X anos para atingir o patrimônio alvo!"`

# %%
### SUA RESPOSTA AQUI ###
