# %% [markdown]
# # EAE1106 - Métodos Computacionais para Economia
# **Faculdade de Economia, Administração, Contabilidade e Atuária (FEA-USP)**
#
# ---
#
# **Professor:** Arthur Augusto Viaro  ([site](https://arthurviaro.github.io))
#
# **Monitora:** Cinthya Beneducci Afonso ([cinthyabeneducci@usp.br](mailto:cinthyabeneducci@usp.br))
#
# ---
#
# ## Lista de Exercícios 1
# **Referência:** Aula 04 - Tipos de Dados e Expressões
#
# *Instruções:* Leia atentamente cada enunciado e utilize os blocos de código abaixo de cada questão para construir e testar as suas respostas.

# %% [markdown]
# ### Exercício 1: Estagiário(a) de Macro
#
# Você é estagiário(a) na área de pesquisa macroeconômica de um grande banco de investimentos. Seu(ua) chefe pediu para você criar um pequeno script que automatize o registro e o cálculo do Produto Interno Bruto (PIB) total de diferentes países na base de dados de vocês. Crie um programa que:
#
# 1. Peça ao usuário para digitar o **nome do país** utilizando a função `input`.
# 2. Peça ao usuário para digitar o **tamanho da população** do país (em milhões de habitantes) e converta a entrada para um número inteiro (`int`).
# 3. Peça ao usuário para digitar o **PIB per capita** do país (em dólares) e converta para um número de ponto flutuante (`float`).
# 4. Calcule uma estimativa para o PIB Total do país (população * PIB per capita) e imprima a frase abaixo formatada utilizando uma **f-string** (`f"...{variavel}..."`):
#
#    > *"O PIB Total de [País] estimado para este ano é de US$ [PIB Total] milhões."*

# %%
### SUA RESPOSTA AQUI ###

# %% [markdown]
# ### Exercício 2: Limpeza de Tickers da B3
#
# Ao raspar dados da internet, os códigos das ações (tickers) muitas vezes vêm sujos, com espaços indesejados e letras minúsculas. Suponha que você raspou o nome de uma ação da bolsa e a string ficou armazenada como: `"   pEtr4      "`.
#
# Crie um programa que trata essa variável e a transforme no padrão correto:
# * Remova qualquer espaço em branco à esquerda e à direita da entrada.
# * Transforme toda a string em MAIÚSCULAS.
#
# Imprima o resultado final na tela.
#
# *Dica: o Python já vem com funções que fazem esses tratamentos na string para você.*

# %%
scraped_data = "   pEtr4      "

### SUA RESPOSTA AQUI ###

# %% [markdown]
# ### Exercício 3: Fatiando a Inflação
#
# Você recebeu de uma API do Banco Central uma `string` contendo a data de divulgação de um índice econômico no formato ISO 8601:
#
# `data_divulgacao = "2026-03-07"`
#
# Usando apenas o conceito de **fatiamento de strings** (slicing) com a sintaxe `string[início:fim]`, extraia e imprima separadamente:
# * O **ano**
# * O **mês**
# * O **dia**
#
# *Dica: Lembre-se de que o Python utiliza indexação baseada em zero.*
#
# *Obs.: o Python tem uma série de funções e métodos da biblioteca datetime `import datetime` para lidar com datas. Por enquanto, tente fazer o exercício apenas usando slicing de string, pois é uma ferramenta importante de se dominar. Teremos oportunidades no futuro para explorar a biblioteca datetime.*

# %%
data_divulgacao = "2026-03-07"

### SUA RESPOSTA AQUI ###

# %% [markdown]
# ### Exercício 4: O Pesadelo do Padrão Brasileiro
#
# Sistemas financeiros no Brasil usam a vírgula para separar casas decimais, enquanto o Python usa o ponto. Imagine que você recebeu o valor `"R$ 1.500,50"` como um texto (`str`).
#
# Crie um programa que utilize o método `replace()` para substituir todas as ocorrências de um trecho de texto por outro:
# 1. Remova o `"R$ "` da string (substituindo por vazio `""`).
# 2. Substitua o ponto `.` (separador de milhar no Brasil) por nada (remova-o).
# 3. Substitua a vírgula `,` (separador decimal no Brasil) por um ponto `.` (padrão do Python).
# 4. Converta a `string` final para um número de ponto flutuante (`float`) e imprima o valor somado a `100`.

# %%
valor = "R$ 1.500,50"

### SUA RESPOSTA AQUI ###

# %% [markdown]
# ### Exercício 5: Exploração, Booleanos e Análise de Sentimentos
#
# Na economia moderna, é muito comum fazermos "Análise de Sentimentos". Isso envolve extrair a emoção ou opinião de textos (como atas do Copom, notícias ou tweets de investidores) e transformá-las em variáveis numéricas, que podem ser contínuas ou "dummies" (1 ou 0), para rodar modelos econométricos.
#
# Imagine que você coletou a seguinte variável contendo o título de uma notícia financeira:
# `noticia = "Otimismo: o desemprego atingiu a menor taxa da última década!"`
#
# **Sua missão:**
# 1. Em uma célula separada, use a função `dir(str)`. Ela funciona como um "mapa" e listará todos os métodos disponíveis para uma string. Encontre pelo nome um método que pareça servir para verificar se um texto **começa com** uma palavra específica.
# 2. Use a função `help()` (por exemplo, `help(str.nome_do_metodo)`) para ler a explicação técnica sobre como esse método funciona e quais argumentos ele aceita.
# 3. Aplique esse método na variável `noticia` para verificar se ela começa com a palavra `"Otimismo"`. Lembre-se que o Python diferencia maiúsculas de minúsculas. Esse método retornará um Booleano (`True` ou `False`).
# 4. Para criar sua variável dummy de sentimento positivo, converta o resultado desse método (o Booleano) em um número inteiro utilizando a função de conversão `int()`.
# 5. Imprima o valor final da sua dummy na tela (deve ser `1` se começar com "Otimismo", indicando sentimento positivo, ou `0` caso contrário).

# %%
noticia = "Otimismo: o desemprego atingiu a menor taxa da última década!"

### SUA RESPOSTA AQUI ###
